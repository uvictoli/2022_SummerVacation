# %% [markdown]
# # 지도 시각화하기

# %%
# folium 설치하기
! pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1.post1-py2.py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 5.0 MB/s eta 0:00:011
# Requirement already satisfied: requests in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.25.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from folium) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.5.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from folium) (1.20.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/yooseungli/opt/anaconda3/lib/python3.8/site-packages (from requests->folium) (4.0.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.5.0 folium-0.12.1.post1

# %%
# 지도시각화를 위해 folium 라이브러리를 사용
import folium

# %% [markdown]
# # 지도 시각화
# - 지도 생성하기
#     - `m` = folium.Map(location = [위도, 경도], zoom_start = 확대정도)
# - 정보 추가하기
#     - 마커 추가하기
#         - folium.Marker([위도, 경도]).add_to(`m`)
#     - 원 추가하기
#         - folium.CircleMarker([위도, 경도], radius=원크기).add_to(`m`)
#     - 추가옵션
#         - tooltip="마우스 올리면 보여질 정보"
#         - popup = "클릭하면 보여질 정보"
#     - 기타) ClickForMarker('체크').add_to(`m`) 지도에서 클릭할 경우 마커 추가하기

# %%
# 지도 생성하기
#먼저, 지도를 펼쳐야 합니다. 지도에서 어느 부분을 살펴볼 것인지, 지도 중심의 좌표를 위도, 경도를 이용해 지정해줍니다.
# 서울역을 기준으로 살펴봅니다. 서울역 : [37.5536067, 126.9674308]
# zoom_start 옵션을 통해 처음에 얼마나 확대해서 볼 것인지를 지정할 수 있습니다.
# 지도가 생성된 뒤에 위치 이동이니 확대/축소를 조정할 수 도 있습니다.

m = folium.Map(location = [37.5536067, 126.9674308], zoom_start = 10)

# Marker([위도, 경도]).add_to(지도이름) 명령을 통해 지도상에 마커를 추가할 수 있으며
# tooltip, popup 옵션을 통해 설명을 추가할 수 있습니다.
# 서울역 [37.5536067, 126.9674308]

# 마커 추가하기
folium.Marker([37.5536067, 126.9674308],
             tooltip = "mouseover",
             popup = "click").add_to(m)

# CircleMarker([위도, 경도]).add_to(지도이름) 명령을 통해 동그라미를 지도에 표시할 수 있습니다.
# 아래 radius 옵션을 통해 동그라미의 크기를 지정할 수 있습니다.
# 서울역 : [37.5536067, 126.9674308]

# 써클마커 추가하기
folium.CircleMarker([37.5536067, 126.9674308],
                   radius = 20, 
                   tooltip = "circleMarker").add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_032e597cf4c29373354fc9709cb8d769 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_032e597cf4c29373354fc9709cb8d769&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_032e597cf4c29373354fc9709cb8d769 = L.map(
#                 &quot;map_032e597cf4c29373354fc9709cb8d769&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3d3b484a9d893730316f9629b0aaa1a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_032e597cf4c29373354fc9709cb8d769);
#
#
#             var marker_f9f01d205205b9934579a76f2d9012b2 = L.marker(
#                 [37.5536067, 126.9674308],
#                 {}
#             ).addTo(map_032e597cf4c29373354fc9709cb8d769);
#
#
#         var popup_0d48b85e9caaf4a5c5b77b5744c2cf89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_774e9f330d930d557cfc9c20ebe5ee81 = $(`&lt;div id=&quot;html_774e9f330d930d557cfc9c20ebe5ee81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;click&lt;/div&gt;`)[0];
#             popup_0d48b85e9caaf4a5c5b77b5744c2cf89.setContent(html_774e9f330d930d557cfc9c20ebe5ee81);
#
#
#         marker_f9f01d205205b9934579a76f2d9012b2.bindPopup(popup_0d48b85e9caaf4a5c5b77b5744c2cf89)
#         ;
#
#
#
#
#             marker_f9f01d205205b9934579a76f2d9012b2.bindTooltip(
#                 `&lt;div&gt;
#                      mouseover
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_ccef2e9c924ff1ce272e3e85e3ea78ea = L.circleMarker(
#                 [37.5536067, 126.9674308],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_032e597cf4c29373354fc9709cb8d769);
#
#
#             circle_marker_ccef2e9c924ff1ce272e3e85e3ea78ea.bindTooltip(
#                 `&lt;div&gt;
#                      circleMarker
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 미니맵을 추가할 경우 MiniMap

# %%
# folium에는 다영한 효과를 줄 수 있는 plugins이 존재하는데 MiniMap이 그 중 하나입니다.
# 미니맵을 자도 우측 하단에 추가하여 현재 어느 위치를 살펴보고 있는지 점검할 수 있습니다.
# 서울역 : [37.5536067, 126.9674308]

from folium.plugins import MiniMap

m = folium.Map(location = [37.5536067, 126.9674308], zoom_start = 12)

# 미니맵 추가
minimap = MiniMap() # M M 대문자
minimap.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c70d0c8b65f458ff3847fed716430556 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c70d0c8b65f458ff3847fed716430556&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c70d0c8b65f458ff3847fed716430556 = L.map(
#                 &quot;map_c70d0c8b65f458ff3847fed716430556&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eec77924b55277a0ca272076f687360 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c70d0c8b65f458ff3847fed716430556);
#
#
#             var tile_layer_9c772600a7c5cc2c12d3814338ef0572 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_a837abc52b16687a1006ff587e5114f9 = new L.Control.MiniMap(
#                 tile_layer_9c772600a7c5cc2c12d3814338ef0572,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_c70d0c8b65f458ff3847fed716430556.addControl(mini_map_a837abc52b16687a1006ff587e5114f9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 서울 대피소 현황 지도 만들기
#
# 서울 대피소 현황 자료를 다운받아 이를 지도에 시각화 해보겠습니다.

# %%
# csv 파일의 표 형태의 데이터를 읽어오기 위해 판다스를 불러옵니다.

import pandas as pd

# %%
# 서울열린데이터광장에 있는 서울시 대피소 현황 자료를 다운 받고, 판다스로 조회하겠습니다.
# encoding = 'cp949' : MS 프로그램 사용시, 그외의 경우 encoding = 'utf-8'

file = '/Users/yooseungli/Downloads/서울시 대피소 방재시설 현황 (좌표계_ WGS1984).csv'

raw = pd.read_csv(file, encoding = 'utf-8') 
raw
# Out:
#      고유번호      대피소명칭                    소재지  최대수용인원  현재수용인원 현재운영여부  \
# 0       2     혜화초등학교      혜화동 13-1 (혜화로 32)     450       0      N
# 1       3       새샘교회               홍제동 20-4     100       0      N
# 2       4     한강중앙교회         포은로2가길 66(합정동)     130       0      N
# 3       5   서울성산초등학교          양화로3길 94(합정동)     200       0      N
# 4       6    상도1동경로당            상도동 159-282      20       0      N
# ..    ...        ...                    ...     ...     ...    ...
# 689   690   홍제3동주민센터               홍제동 7-13      30       0      N
# 690   691    원광종합복지관             신내1동 572-2    3472       0      N
# 691   692     원묵초등학교      묵1동 11(숙선옹주로 109)     880       0      N
# 692   693     중원초등학교  중계2동 502(노원구 섬밭길 316)     490       0      N
# 693   694  암사3동 주민센터          강동구 암사동 414-2       0       0      N
#
#               전화번호     행정동코드   행정동명칭 대피단계 비고          경도         위도
# 0         763-0606  11110650     혜화동          126.999891  37.589128
# 1         720-7040  11410655    홍제2동          126.950484  37.583660
# 2         337-6629  11440680     합정동          126.910028  37.549343
# 3         324-1407  11440680     합정동          126.910666  37.553495
# 4    010-8011-7330  11590530    상도1동          126.948269  37.500395
# ..             ...       ...     ...  ... ..         ...        ...
# 689       330-8420  11410640    홍제3동          126.949711  37.593764
# 690       438-4011  11260680    신내1동          127.095956  37.604360
# 691      3421-2102  11260620     묵1동          127.086290  37.617983
# 692       971-4771  11350625  중계2.3동          127.062806  37.643853
# 693       442-2582  11740590    암사3동          127.140775  37.554998
#
# [694 rows x 13 columns]

# %%
# 파일에서 읽어온 데이터를 살펴보겠습니다.
raw.head()
# Out:
#    고유번호     대피소명칭                소재지  최대수용인원  현재수용인원 현재운영여부           전화번호  \
# 0     2    혜화초등학교  혜화동 13-1 (혜화로 32)     450       0      N       763-0606
# 1     3      새샘교회           홍제동 20-4     100       0      N       720-7040
# 2     4    한강중앙교회     포은로2가길 66(합정동)     130       0      N       337-6629
# 3     5  서울성산초등학교      양화로3길 94(합정동)     200       0      N       324-1407
# 4     6   상도1동경로당        상도동 159-282      20       0      N  010-8011-7330
#
#       행정동코드 행정동명칭 대피단계 비고          경도         위도
# 0  11110650   혜화동          126.999891  37.589128
# 1  11410655  홍제2동          126.950484  37.583660
# 2  11440680   합정동          126.910028  37.549343
# 3  11440680   합정동          126.910666  37.553495
# 4  11590530  상도1동          126.948269  37.500395

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694 entries, 0 to 693
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   고유번호    694 non-null    int64
#  1   대피소명칭   694 non-null    object
#  2   소재지     694 non-null    object
#  3   최대수용인원  694 non-null    int64
#  4   현재수용인원  694 non-null    int64
#  5   현재운영여부  694 non-null    object
#  6   전화번호    694 non-null    object
#  7   행정동코드   694 non-null    int64
#  8   행정동명칭   694 non-null    object
#  9   대피단계    694 non-null    object
#  10  비고      694 non-null    object
#  11  경도      694 non-null    float64
#  12  위도      694 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 70.6+ KB

# %%
# 인덱스 번호가 0인 경우, 위도와 경도 데이터를 출력해보겠습니다.

i = 0

lat = raw.loc[i, '위도'] #인덱스가 0이고 컬럼명이 '위도'인 값
long = raw.loc[i, '경도']

print(lat, long)
# Out:
# 37.5891283 126.9998906

# %%
raw.head()
# Out:
#    고유번호     대피소명칭                소재지  최대수용인원  현재수용인원 현재운영여부           전화번호  \
# 0     2    혜화초등학교  혜화동 13-1 (혜화로 32)     450       0      N       763-0606
# 1     3      새샘교회           홍제동 20-4     100       0      N       720-7040
# 2     4    한강중앙교회     포은로2가길 66(합정동)     130       0      N       337-6629
# 3     5  서울성산초등학교      양화로3길 94(합정동)     200       0      N       324-1407
# 4     6   상도1동경로당        상도동 159-282      20       0      N  010-8011-7330
#
#       행정동코드 행정동명칭 대피단계 비고          경도         위도
# 0  11110650   혜화동          126.999891  37.589128
# 1  11410655  홍제2동          126.950484  37.583660
# 2  11440680   합정동          126.910028  37.549343
# 3  11440680   합정동          126.910666  37.553495
# 4  11590530  상도1동          126.948269  37.500395

# %%
len(raw)
# Out:
# 694

# %%
# 모든 인덱스 번호에 대해서 위도, 경도, 명칭을 출력하겠습니다.

for i in range(len(raw)):
    lat = raw.loc[i, '위도'] 
    long = raw.loc[i, '경도']
    name = raw.loc[i, '대피소명칭']

    print(lat, long, name)
# Out:
# 37.5891283 126.9998906 혜화초등학교
# 37.5836603 126.9504844 새샘교회
# 37.5493434 126.9100281 한강중앙교회
# 37.5534953 126.9106658 서울성산초등학교
# 37.5003954 126.9482686 상도1동경로당
# 37.4997347 126.9374323 상도초등학교
# 37.5100544 126.9536402 본동초교
# 37.5365343 126.9650202 남정초등학교
# 37.5884354 126.9217785 응암초등학교
# 37.5030252 126.9625144 제일감리교회
# 37.4866976 126.9576162 봉천종합사회복지관
# 37.5232077 126.9368097 여의도초등학교
# 37.4830902 126.9787764 사당1동주민센터
# 37.5283727 126.9537102 서부성결교회
# 37.4811316 126.9901108 서울 이수 중학교
# 37.5459029 126.9535807 서울공덕초등학교
# 37.4937422 126.9440685 국사봉중학교
# 37.4910611 126.9553258 봉현초등학교
# 37.5911343 127.0021399 천주교 외방선교회
# 37.5484412 127.0628283 성동세무서
# 37.5147612 127.1130378 방이중학교
# 37.4998298 127.1079155 가락초등학교
# 37.5444065 127.0629919 성수초교
# 37.5159073 127.0878144 잠신초등학교
# 37.484888 127.0934544 태화기독교종합 사회복지관
# 37.5172332 127.099344 잠실중학교
# 37.6198317 127.0055226 정릉초등학교
# 37.5303512 127.0853523 광양중학교
# 37.5778498 127.0244276 대광고등학교
# 37.6403265 127.0229092 성실교회교육관
# 37.4891812 127.1112013 가원초등학교
# 37.6708916 127.0457558 도봉중학교
# 37.6564809 127.0284014 쌍문4동주민센터
# 37.4797843 126.9856123 방배2동 주민센터
# 37.497947 127.1394478 보인고등학교
# 37.4868368 127.0704134 개포초등학교
# 37.4955053 127.1526489 마천초등학교
# 37.6621603 127.0278544 학마을다사랑센터
# 37.5197002 127.134857 보성중고등학교
# 37.538511 127.1448722 길동초등학교
# 37.587503 127.0224721 안암초등학교
# 37.6140774 127.0436751 장위1동 주민센터
# 37.6488034 127.046758 창일중학교
# 37.4991267 127.1001476 남현교회
# 37.5023094 127.1130719 잠실여자고등학교
# 37.5544231 127.1420279 명일초등학교
# 37.4885099 126.8500846 개웅초등학교
# 37.515637 126.8894872 성결교회
# 37.6205029 127.0688592 한천초등학교
# 37.4853903 126.8838479 영일초등학교
# 37.5321157 126.8477954 화곡 경로당
# 37.4983265 126.9134649 대길초등학교
# 37.6323901 127.0660794 중현초등학교
# 37.5162167 126.8440456 신남초등학교
# 37.6507925 127.0731328 을지초등학교
# 37.5501512 127.0875822 선화예술학교(중학교)
# 37.5937638 126.9497106 홍제3동주민센터
# 37.6043596 127.0959559 원광종합복지관
# 37.6179826 127.0862899 원묵초등학교
# 37.6438528 127.0628056 중원초등학교
# 37.5549978 127.140775 암사3동 주민센터

# %%
# 지도를 생성한 뒤, 위도/경도에 맞게 지도에 마커를 추가하겠습니다.
# 중심위치 : 서울역 [37.5536067, 126.9674308]

# 지도 생성하기
m = folium.Map(location = [37.5536067, 126.9674308],
              zoom_start = 12)

# 대피소 마커 추가하기
for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i, '대피소명칭']

    folium.Marker([lat, long],
                 tooltip = name).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b91660bddaecbc2635657f96147844 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b91660bddaecbc2635657f96147844&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_29b91660bddaecbc2635657f96147844 = L.map(
#                 &quot;map_29b91660bddaecbc2635657f96147844&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be58e36c7efd2a64d2edbe5476c71a60 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             var marker_17058b96a7ffb05b1815a919052fcc4e = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_17058b96a7ffb05b1815a919052fcc4e.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_31ab59f4399031284543f1237e6961e5 = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_31ab59f4399031284543f1237e6961e5.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_981dd57b27df21d28f35042c67ba0a79 = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_981dd57b27df21d28f35042c67ba0a79.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_267d2ead4e1b696bbeb0b15f9f1d1415 = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_267d2ead4e1b696bbeb0b15f9f1d1415.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_89ca07a4fd54b64140a6337554eafae1 = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_89ca07a4fd54b64140a6337554eafae1.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_200db8b160ba6d51d8387f9e6e6543d7 = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_200db8b160ba6d51d8387f9e6e6543d7.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_af3982946af793bb594b160eab5b3084 = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_af3982946af793bb594b160eab5b3084.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3da54a4bd9581ef2e5e54ad9274ca5b9 = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_3da54a4bd9581ef2e5e54ad9274ca5b9.bindTooltip(
#                 `&lt;div&gt;
#                      남정초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b285f8938d9a7981bfcc74656375cf43 = L.marker(
#                 [37.5884354, 126.9217785],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_b285f8938d9a7981bfcc74656375cf43.bindTooltip(
#                 `&lt;div&gt;
#                      응암초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5e2fa40df542991910e07ae12ae4bdb0 = L.marker(
#                 [37.5030252, 126.9625144],
#                 {}
#             ).addTo(map_29b91660bddaecbc2635657f96147844);
#
#
#             marker_5e2fa40df542991910e07ae12ae4bdb0.bindTooltip(
#                 `&lt;div&gt;
#                      제일감리교회
#                  &lt;/div&gt;`,

# %%
m.save('./Sheltermap.html')

# %% [markdown]
# ## 마커가 너무 많을 때에는 살펴 보는 것이 어려울 수 있습니다.
# ## -> ClusterMarker를 이용해 근처에 있는 마커들끼리는 그룹으로 표현

# %%
# MarkerCluster 라이브러리를 불러오겠습니다.

from folium.plugins import MarkerCluster

# %%
# MarkerCluster를 이용해 대피소 정보를 시각화 하겠습니다.

# 지도 생성하기
m = folium.Map(location = [37.5536067, 126.9674308],
              zoom_start = 12)

marker_cluster = MarkerCluster().add_to(m)

# 대피소 마커 추가하기
for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i, '대피소명칭']

    folium.Marker([lat, long],
                 tooltip = name).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_249f04e8ed85ab4a08397a47be04782f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_249f04e8ed85ab4a08397a47be04782f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_249f04e8ed85ab4a08397a47be04782f = L.map(
#                 &quot;map_249f04e8ed85ab4a08397a47be04782f&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81a0e79a4e48f9417b9a03d3fdcda670 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_249f04e8ed85ab4a08397a47be04782f);
#
#
#             var marker_cluster_11093b89c5108bcb58da41d7cc49ed49 = L.markerClusterGroup(
#                 {}
#             );
#             map_249f04e8ed85ab4a08397a47be04782f.addLayer(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             var marker_2f3bbe93ca1d1f2fbac366758f34d971 = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_2f3bbe93ca1d1f2fbac366758f34d971.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fbbbcac0b73c6ba552fff50ce4b03033 = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_fbbbcac0b73c6ba552fff50ce4b03033.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bce46f794bcd727715402e3c0e8d0160 = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_bce46f794bcd727715402e3c0e8d0160.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_09d45e7d79412570321ff5be657ac5ba = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_09d45e7d79412570321ff5be657ac5ba.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_1af9cf3b172aadcd7794fa8b4eeac31d = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_1af9cf3b172aadcd7794fa8b4eeac31d.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d84b98e047dbe0ade11287fecec8572c = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_d84b98e047dbe0ade11287fecec8572c.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5f1d193bf755f09c3776049415a09116 = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_5f1d193bf755f09c3776049415a09116.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_688b0601187da6778d31c8f35975d966 = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(marker_cluster_11093b89c5108bcb58da41d7cc49ed49);
#
#
#             marker_688b0601187da6778d31c8f35975d966.bindTooltip(
#                 `&lt;div&gt;
#                      남정초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );

# %% [markdown]
# ## 미니맵 추가하고 싶을 때는 MiniMap

# %%
from folium.plugins import MiniMap

# %%
# 미니맵과 클러스터 마커를 이용해 대피소 정보를 지도에 시각화 하겠습니다.
#  서울역 중심 [37.5536067, 126.9674308]
# 위치명 / 수용인원을 추가하여 지도 만들기

# 지도 생성하기
m = folium.Map(location = [37.5536067, 126.9674308],
              zoom_start = 12)

marker_cluster = MarkerCluster().add_to(m)

minimap = MiniMap()
minimap.add_to(m)

# 대피소 마커 추가하기
for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i, '대피소명칭']

    folium.Marker([lat, long],
                 tooltip = name).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_decf89e2d51cf7cce54f71a56192b93a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_decf89e2d51cf7cce54f71a56192b93a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_decf89e2d51cf7cce54f71a56192b93a = L.map(
#                 &quot;map_decf89e2d51cf7cce54f71a56192b93a&quot;,
#                 {
#                     center: [37.5536067, 126.9674308],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d16d1af1feea9aa9c0f8e84e9909d5c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_decf89e2d51cf7cce54f71a56192b93a);
#
#
#             var marker_cluster_18e84089144b66f13bab713ea8f901c9 = L.markerClusterGroup(
#                 {}
#             );
#             map_decf89e2d51cf7cce54f71a56192b93a.addLayer(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             var marker_92a4f24e3c276676ab2e46526278198b = L.marker(
#                 [37.5891283, 126.9998906],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_92a4f24e3c276676ab2e46526278198b.bindTooltip(
#                 `&lt;div&gt;
#                      혜화초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e22d3b2a32a0b380cf8e33b3bdc3e864 = L.marker(
#                 [37.5836603, 126.9504844],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_e22d3b2a32a0b380cf8e33b3bdc3e864.bindTooltip(
#                 `&lt;div&gt;
#                      새샘교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3d6c11c7844cea3fe09e997388741d09 = L.marker(
#                 [37.5493434, 126.9100281],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_3d6c11c7844cea3fe09e997388741d09.bindTooltip(
#                 `&lt;div&gt;
#                      한강중앙교회
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ad9cae3108a298f2ee69fe93c350f61 = L.marker(
#                 [37.5534953, 126.9106658],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_8ad9cae3108a298f2ee69fe93c350f61.bindTooltip(
#                 `&lt;div&gt;
#                      서울성산초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a0e9e6283d9f8111c3bdcf32f183e70b = L.marker(
#                 [37.5003954, 126.9482686],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_a0e9e6283d9f8111c3bdcf32f183e70b.bindTooltip(
#                 `&lt;div&gt;
#                      상도1동경로당
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_62c33c54315916ced2b8759cdbb77dcf = L.marker(
#                 [37.4997347, 126.9374323],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_62c33c54315916ced2b8759cdbb77dcf.bindTooltip(
#                 `&lt;div&gt;
#                      상도초등학교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_854ec40fd2b5e18727ea33f0d54695b2 = L.marker(
#                 [37.5100544, 126.9536402],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66f13bab713ea8f901c9);
#
#
#             marker_854ec40fd2b5e18727ea33f0d54695b2.bindTooltip(
#                 `&lt;div&gt;
#                      본동초교
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_17ed3fad6eacd83127a158b2a01e5031 = L.marker(
#                 [37.5365343, 126.9650202],
#                 {}
#             ).addTo(marker_cluster_18e84089144b66

# %%
# 이렇게 생성한 지도를 html 확장자로 저장할 경우, 필요항 때 언제나 다시 열어서 지도를 움직여 가며 정보를 확인할 수 있습니다.

m.save('./Sheltermap.html')
